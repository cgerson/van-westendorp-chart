# %%
# %matplotlib inline 

import sys 
sys.path.insert(0, "../")
import chart_vw # import module

reload(chart_vw)
# Out:
# <module 'chart_vw' from '../chart_vw.py'>

# %%
# instantiate and clean
# pricing_data_file_path is expected to be in "data" directory

obj = chart_vw.ChartObject(pricing_data_file_path = "../data/example_data.csv")
# Out:
# size: 201
#
# cheap
# size before outlier removal: 201
# size after outlier removal: 190
#
# bargain
# size before outlier removal: 190
# size after outlier removal: 188
#
# getting expensive
# size before outlier removal: 188
# size after outlier removal: 183
#
# too expensive
# size before outlier removal: 183
# size after outlier removal: 176
#
# size after removing illogical responses: 145

# %%
# optional: set new plot style
# ['seaborn-darkgrid', 'seaborn-notebook', 'classic', 'seaborn-ticks', 'grayscale', 'bmh', 'seaborn-talk', 'dark_background', 'ggplot', 'fivethirtyeight', 'seaborn-colorblind', 'seaborn-deep', 'seaborn-whitegrid', 'seaborn-bright', 'seaborn-poster', 'seaborn-muted', 'seaborn-paper', 'seaborn-white', 'seaborn-pastel', 'seaborn-dark', 'seaborn-dark-palette']

obj.set_style('seaborn-darkgrid')

# %%
# plot Optimal Price Point (OPP)
# optional: annotate chart by setting "annotate" to true and populating OPP_coords
# optional: save chart png by specifying a "chart_path"

obj.plot(intersection="opp", title = "Example", chart_path= "../charts/example_chart.png", 
         annotate=True, OPP_coords=(12,29))

# %%
# plot Range of Acceptable Prices
# optional: annotate chart by setting "annotate" to true and populating PMC_coords and PME_coords
# optional: save chart png by specifying a "chart_path"

obj.plot(intersection="range", title = "Profie No Data", chart_path=False, 
         annotate=True, 
         PMC_coords=(4,62), PME_coords=(20,43))
