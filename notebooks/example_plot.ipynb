# %%
# %matplotlib inline 

import sys 
sys.path.insert(0, "../")
import chart_vw # import module

reload(chart_vw)
# Out:
# <module 'chart_vw' from '../chart_vw.pyc'>

# %%
obj = chart_vw.ChartObject(pricing_data_file_path = "example_data.csv")
# Out:
# size: 30
#
# cheap
# size before outlier removal: 30
# size after outlier removal: 30
#
# bargain
# size before outlier removal: 30
# size after outlier removal: 30
#
# getting expensive
# size before outlier removal: 30
# size after outlier removal: 30
#
# too expensive
# size before outlier removal: 30
# size after outlier removal: 30
#
# size after removing illogical responses: 25

# %%
obj.chart_data(intersection= "opp", title = "Example")
